# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('metadata.json.gz')
df[df["asin"] == "B001KXZ808"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-499543be80be> in <cell line: 17>()
#      15   return pd.DataFrame.from_dict(df, orient='index')
#      16
# ---> 17 df = getDF('metadata.json.gz')
#      18 df[df["asin"] == "B001KXZ808"]
#
# <ipython-input-1-499543be80be> in getDF(path)
#      10   i = 0
#      11   df = {}
# ---> 12   for d in parse(path):
#      13     df[i] = d
#      14     i += 1
#
# <ipython-input-1-499543be80be> in parse(path)
#       3
#       4 def parse(path):
# ----> 5   g = gzip.open(path, 'rb')
#       6   for l in g:
#       7     yield eval(l)
#
# /usr/lib/python3.10/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
# ...
